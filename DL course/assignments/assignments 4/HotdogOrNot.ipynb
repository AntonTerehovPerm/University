# %%
#Сделано в google colab
#https://colab.research.google.com/drive/1C6LVw2XPtLSPLRe5wRDub3a22eDQ1OWZ#scrollTo=BYxGFPhWCl7p

# %% [markdown]
# # Задание 4 - Перенос обучения (transfer learning) и тонкая настройка (fine-tuning)
#
# Одной из важнейшних техник в тренировке сетей - использовать заранее натренированные веса на более общей задачи в качестве начальной точки, а потом "дотренировать" их на конкретной.
#
# Такой подход и убыстряет обучение, и позволяет тренировать эффективные модели на маленьких наборах данных.
#
# В этом упражнении мы натренируем классификатор, который отличает хотдоги от не хотдогов!
# (более подробно - https://www.youtube.com/watch?v=ACmydtFDTGs)
#
# Это задание требует доступа к GPU, поэтому его можно выполнять либо на компьютере с GPU от NVidia, либо в [Google Colab](https://colab.research.google.com/).

# %% [markdown]
# Сначала давайте скачаем данные с картинками. Это сделает код в следующей ячейке. Данные будут разделены на две части. На обучающей выборке, которая будет храниться в папке **train_kaggle**, мы будем строить наши модели, а на тестовой выборке **test_kaggle** будем предсказывать класс, к которому относится фотография (хотдог или нет).
#
# ### Если вы в Google Colab!
#
# В нем можно запускать ноутбуки с доступом к GPU. Они не очень быстрые, зато бесплатные!
# Каждый ноутбук получает свой собственный environment c доступным диском итд.
#
# Через 90 минут отсуствия активности этот environment пропадает со всеми данными.
# Поэтому нам придется скачивать данные каждый раз.

# %%
# !pip3 install google.colab
# Out:
#       Successfully uninstalled google-auth-1.7.2
#   Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
#   Found existing installation: pandas 1.0.3
#     Uninstalling pandas-1.0.3:
#       Successfully uninstalled pandas-1.0.3
#   Found existing installation: portpicker 1.3.1
#     Uninstalling portpicker-1.3.1:
#       Successfully uninstalled portpicker-1.3.1
#   Found existing installation: idna 2.9
#     Uninstalling idna-2.9:
#       Successfully uninstalled idna-2.9
#   Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed google-auth-1.4.2 google.colab idna-2.8 ipykernel-4.6.1 pandas-0.24.2 portpicker-1.2.0 requests-2.21.0

# %%
import os
import json
import csv
import urllib
from io import BytesIO
from PIL import Image

from socket import timeout

from google.colab import files

# %%
# !pip3 install -q torch torchvision
# !pip3 install -q Pillow
# Out:
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.

# %%
import torch
from torchvision import models
from torch.utils.data import Dataset, SubsetRandomSampler
from torchvision import transforms

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

device = torch.device("cuda:0") # Let's make sure GPU is available

# %% [markdown]
# # Collab

# %%
# Download train data
# !wget "https://storage.googleapis.com/dlcourse_ai/train.zip"
# !unzip -q "train.zip"

train_folder = "train_kaggle/"
# Count number of files in the train folder, should be 4603
print('Number of files in the train folder', len(os.listdir(train_folder)))

# Download test data
# !wget "https://storage.googleapis.com/dlcourse_ai/test.zip"
# !unzip -q "test.zip"

test_folder = "test_kaggle/"
# Count number of files in the test folder, should be 1150
print('Number of files in the test folder', len(os.listdir(test_folder)))
# Out:
# --2020-05-14 00:42:25--  https://storage.googleapis.com/dlcourse_ai/train.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.68.128, 2404:6800:4003:c03::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.68.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 562348083 (536M) [application/zip]
# Saving to: ‘train.zip’
#
# train.zip           100%[===================>] 536.30M  35.7MB/s    in 15s
#
# 2020-05-14 00:42:42 (34.9 MB/s) - ‘train.zip’ saved [562348083/562348083]
#
# Number of files in the train folder 4603
# --2020-05-14 00:42:51--  https://storage.googleapis.com/dlcourse_ai/test.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.68.128, 2404:6800:4003:c04::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.68.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 140788786 (134M) [application/zip]
# Saving to: ‘test.zip’
#
# test.zip            100%[===================>] 134.27M  16.3MB/s    in 8.2s
#
# 2020-05-14 00:43:00 (16.3 MB/s) - ‘test.zip’ saved [140788786/140788786]
#
# Number of files in the test folder 1150

# %% [markdown]
# # Home

# %%
import requests

# %%
f=open(r'test.zip',"wb")
ufr = requests.get("https://storage.googleapis.com/dlcourse_ai/test.zip")
f.write(ufr.content)
try: os.mkdir("test_kaggle")
except: pass
f.close()
# !unzip -q "test.zip"
# Out:
# replace test_kaggle/10000.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace test_kaggle/10001.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace test_kaggle/10002.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
f=open(r'train.zip',"wb")
ufr = requests.get("https://storage.googleapis.com/dlcourse_ai/train.zip")
f.write(ufr.content)
try: os.mkdir("train_kaggle")
except: pass
f.close()
# !unzip -q "train.zip"

# %% [markdown]
# # Основная работа

# %%
train_folder = "train_kaggle/"
# Count number of files in the train folder, should be 4603
print('Number of files in the train folder', len(os.listdir(train_folder)))


test_folder = "test_kaggle/"
# Count number of files in the test folder, should be 1150
print('Number of files in the test folder', len(os.listdir(test_folder)))
# Out:
# Number of files in the train folder 4603
# Number of files in the test folder 1150

# %% [markdown]
# # Имплементируем свой Dataset для загрузки данных
#
# В этом задании мы реализуем свой собственный класс Dataset для загрузки данных. Его цель - загрузить данные с диска и выдать по ним тензор с входом сети, меткой и идентификатором картинки (так будет проще подготовить сабмит для kaggle на тестовых данных).
#
# Вот ссылка, где хорошо объясняется как это делать на примере: https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
#
# Ваш Dataset должен в качестве количества сэмплов выдать количество файлов в папке и уметь выдавать кортеж из сэмпла, метки по индексу и названия файла.
# Если название файла начинается со слов 'frankfurter', 'chili-dog' или 'hotdog' - метка положительная. Иначе отрицательная (ноль).
#
# И не забудьте поддержать возможность трансформации входа (аргумент `transforms`), она нам понадобится!

# %%
class HotdogOrNotDataset():
    def __init__(self, folder, transform=None):
        self.transform = transform
        self.folder = folder
        
    def __len__(self):
        return len(os.listdir(self.folder))
    
    def __getitem__(self, index):        
        img_name = os.listdir(self.folder)[index]
        img_path = os.path.join(self.folder, img_name)

        img = Image.open(img_path)
        if self.transform:
            img = self.transform(img)
        
        y = 1 if any(x in img_name for x in ['frankfurter', 'chili-dog', 'hotdog']) else 0
        
        img_id = img_name.split('_')[1].split('.')[0]

        return img, y, img_id

def visualize_samples(dataset, indices, title=None, count=10):
    # visualize random 10 samples
    plt.figure(figsize=(count*3,3))
    display_indices = indices[:count]
    if title:
        plt.suptitle("%s %s/%s" % (title, len(display_indices), len(indices)))        
    for i, index in enumerate(display_indices):    
        x, y, _ = dataset[index]
        plt.subplot(1,count,i+1)
        plt.title("Label: %s" % y)
        plt.imshow(x)
        plt.grid(False)
        plt.axis('off')   
    
orig_dataset = HotdogOrNotDataset(train_folder)
indices = np.random.choice(np.arange(len(orig_dataset)), 7, replace=True)

visualize_samples(orig_dataset, indices, "Samples")

# %%
# Let's make sure transforms work!
dataset = HotdogOrNotDataset(train_folder, transform=transforms.RandomVerticalFlip(0.9))
visualize_samples(dataset, indices, "Samples with flip - a lot should be flipped!")

# %% [markdown]
# # Создаем Dataset для тренировки
#
# И разделяем его на train и validation.
# На train будем обучать модель, на validation проверять ее качество, а соревнование Kaggle In-Class проведем на фотографиях из папки test_kaggle.

# %%
# First, lets load the dataset
train_dataset = HotdogOrNotDataset(train_folder, 
                       transform=transforms.Compose([
                           transforms.Resize((224, 224)),
                           transforms.ToTensor(),
                           # Use mean and std for pretrained models
                           # https://pytorch.org/docs/stable/torchvision/models.html
                           transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])                         
                       ])
                      )
test_dataset = HotdogOrNotDataset(test_folder, 
                       transform=transforms.Compose([
                           transforms.Resize((224, 224)),
                           transforms.ToTensor(),
                           # Use mean and std for pretrained models
                           # https://pytorch.org/docs/stable/torchvision/models.html
                           transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])                         
                       ])
                      )

# %%
batch_size = 64

data_size = len(dataset)
validation_fraction = .2


val_split = int(np.floor((validation_fraction) * data_size))
indices = list(range(data_size))
np.random.seed(42)
np.random.shuffle(indices)

val_indices, train_indices = indices[:val_split], indices[val_split:]

train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, 
                                           sampler=train_sampler)
val_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                         sampler=val_sampler)
# Notice that we create test data loader in a different way. We don't have the labels.
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size)

# %% [markdown]
# Наши обычные функции для тренировки

# %%
def train_model(model, train_loader, val_loader, loss, optimizer, num_epochs):    
    loss_history = []
    train_history = []
    val_history = []
    for epoch in range(num_epochs):
        model.train() # Enter train mode
        
        loss_accum = 0
        correct_samples = 0
        total_samples = 0
        for i_step, (x, y,_) in enumerate(train_loader):
          
            x_gpu = x.to(device)
            y_gpu = y.to(device)
            prediction = model(x_gpu)    
            loss_value = loss(prediction, y_gpu)
            optimizer.zero_grad()
            loss_value.backward()
            optimizer.step()
            
            _, indices = torch.max(prediction, 1)
            correct_samples += torch.sum(indices == y_gpu)
            total_samples += y.shape[0]
            
            loss_accum += loss_value

        ave_loss = loss_accum / i_step
        train_accuracy = float(correct_samples) / total_samples
        val_accuracy = compute_accuracy(model, val_loader)
        
        loss_history.append(float(ave_loss))
        train_history.append(train_accuracy)
        val_history.append(val_accuracy)
        
        print("Average loss: %f, Train accuracy: %f, Val accuracy: %f" % (ave_loss, train_accuracy, val_accuracy))
        
    return loss_history, train_history, val_history
        
def compute_accuracy(model, loader):
    """
    Computes accuracy on the dataset wrapped in a loader
    
    Returns: accuracy as a float value between 0 and 1
    """
    model.eval() # Evaluation mode
    acc = [torch.mean((model(batch[0].to(device)).argmax(axis=1) == batch[1].to(device)).float()) 
           for batch in loader]
    acc = torch.mean(torch.Tensor(acc))
    return acc

# %% [markdown]
# # Использование заранее натренированной сети (pretrained network)
#
# Чаще всего в качестве заранее натренированной сети используется сеть, натренированная на данных ImageNet с 1M изображений и 1000 классами.
#
# PyTorch включает такие натренированные сети для различных архитектур (https://pytorch.org/docs/stable/torchvision/models.html)
# Мы будем использовать ResNet18.
#
# Для начала посмотрим, что выдает уже натренированная сеть на наших картинках. То есть, посмотрим к какому из 1000 классов их отнесет сеть.
#
# Запустите модель на 10 случайных картинках из датасета и выведите их вместе с классами с наибольшей вероятностью.
# В коде уже есть код, который формирует соответствие между индексами в выходном векторе и классами ImageNet.

# %%
# Thanks to https://discuss.pytorch.org/t/imagenet-classes/4923/2
def load_imagenet_classes():
    classes_json = urllib.request.urlopen('https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json').read()
    classes = json.loads(classes_json)
    
    # TODO: Process it to return dict of class index to name
    return { int(k): v[-1] for k, v in classes.items()}
    
model = models.resnet18(pretrained=True)

# TODO: Run this model on 10 random images of your dataset and visualize what it predicts
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))

# %%
indices = np.random.choice(np.arange(len(orig_dataset)), 10, replace=False)
classes = load_imagenet_classes()

plt.figure(figsize=(10*3,3))
model.eval()
for ind, value in enumerate(indices):
    plt.subplot(1,10,ind+1)
    img, y, _ = train_dataset[value]
    img = img.unsqueeze(0)
    ans = model(img)
    _, ans = torch.max(ans, 1)
    plt.title(f"Predict as {classes[int(ans)]}")
    img, y, _ = dataset[value]
    plt.imshow(img)
    plt.grid(False)
    plt.axis('off')

# %% [markdown]
# # Перенос обучения (transfer learning) - тренировать только последний слой
#
# Существует несколько вариантов переноса обучения, мы попробуем основные.
# Первый вариант - заменить последний слой на новый и тренировать только его, заморозив остальные.

# %%
import torch.nn as nn
import torch.optim as optim


model = models.resnet18(pretrained=True)
for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

model.type(torch.cuda.FloatTensor)
model.to(device)

parameters = model.fc.parameters()

loss = nn.CrossEntropyLoss().type(torch.cuda.FloatTensor)
optimizer = optim.SGD(parameters, lr=0.001, momentum=0.9)

loss_history, train_history, val_history = train_model(model, train_loader, val_loader, loss, optimizer, 2)
# Out:
# Average loss: 0.386372, Train accuracy: 0.815096, Val accuracy: 0.927431
# Average loss: 0.213310, Train accuracy: 0.916644, Val accuracy: 0.943403

# %% [markdown]
# # Перенос обучения (transfer learning) - тренировать всю модель
#
# Второй вариант - точно так же заменить последгний слой на новый и обучать всю модель целиком.

# %%
import torch.nn as nn
import torch.optim as optim

model = models.resnet18(pretrained=True)
# TODO: Add a new output layer and train the whole model
# https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

model.type(torch.cuda.FloatTensor)
model.to(device)

parameters = model.parameters()

loss = nn.CrossEntropyLoss()
optimizer = optim.SGD(parameters, lr=0.001, momentum=0.9)

loss_history, train_history, val_history = train_model(model, train_loader, 
                                                       val_loader, loss, 
                                                       optimizer, 2)
# Out:
# Average loss: 0.310391, Train accuracy: 0.861797, Val accuracy: 0.949306
# Average loss: 0.135247, Train accuracy: 0.952484, Val accuracy: 0.952431

# %% [markdown]
# # Перенос обучения (transfer learning) - разные скорости обучения для разных слоев
#
# И наконец последний вариант, который мы рассмотрим - использовать разные скорости обучения для новых и старых слоев

# %%
import torch.nn as nn
import torch.optim as optim

model = models.resnet18(pretrained=True)
loss = nn.CrossEntropyLoss()

num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

model.type(torch.cuda.FloatTensor)
model.to(device)

parameters = [{'params': list(model.parameters())[:-1], 'lr': 1e-2},
              {'params': list(model.parameters())[-1:], 'lr': 1e-3}]

optimizer = optim.SGD(parameters, momentum=0.9)

loss_history, train_history, val_history = train_model(model, train_loader, 
                                                       val_loader, loss, 
                                                       optimizer, 2)
# Out:
# Average loss: 0.251416, Train accuracy: 0.897095, Val accuracy: 0.919792
# Average loss: 0.077427, Train accuracy: 0.972305, Val accuracy: 0.942014

# %% [markdown]
# # Визуализируем метрики и ошибки модели
#
# Попробуем посмотреть, где модель ошибается - визуализируем ложные срабатывания (false positives) и ложноотрицательные срабатывания (false negatives).
#
# Для этого мы прогоним модель через все примеры и сравним ее с истинными метками (ground truth).

# %%
from torch.utils.data.sampler import Sampler

class SubsetSampler(Sampler):
    r"""Samples elements with given indices sequentially

    Arguments:
        data_source (Dataset): dataset to sample from
        indices (ndarray): indices of the samples to take
    """

    def __init__(self, indices):
        self.indices = indices

    def __iter__(self):
        return (self.indices[i] for i in range(len(self.indices)))

    def __len__(self):
        return len(self.indices)
    
    
def evaluate_model(model, dataset, indices):
    """
    Computes predictions and ground truth labels for the indices of the dataset
    
    Returns: 
    predictions: np array of booleans of model predictions
    grount_truth: np array of boolean of actual labels of the dataset
    """
    model.eval() # Evaluation mode
    loader = torch.utils.data.DataLoader(dataset, 
                                         sampler=SubsetSampler(indices))
    predictions = []
    ground_truth = []
  
    for i_step, (x, y, _) in enumerate(loader):
        x_gpu = x.to(device)
        y_gpu = y.to(device)
        pred = model(x_gpu)
        _, indices = torch.max(pred, 1)
        predictions.append(int(indices))
        ground_truth.append(int(y_gpu))
    return predictions, ground_truth

predictions, gt = evaluate_model(model, train_dataset, val_indices)

# %% [markdown]
# И теперь можно визуализировать false positives и false negatives.

# %%
def get_fp_and_fn_samples(predictions, gt, val_indices):
    false_positive_indices = []
    false_negative_indices = []

    for ind, gts in enumerate(gt):
        if not gts and gts != predictions[ind]:
            false_positive_indices.append(val_indices[ind])
        if gts and gts != predictions[ind]:
            false_negative_indices.append(val_indices[ind])
    return false_positive_indices, false_negative_indices

# %%
false_positive_indices, false_negative_indices = \
                       get_fp_and_fn_samples(predictions, gt, val_indices)

visualize_samples(orig_dataset, false_positive_indices, "False positives")

visualize_samples(orig_dataset, false_negative_indices, "False negatives")

# %%
import sklearn.metrics as metrics

def binary_classification_metrics(prediction, ground_truth):
    b = 1

    true_positive = 0
    false_positive = 0
    true_negative = 0
    false_negative = 0

    for i in range(len(ground_truth)):
        if prediction[i] == ground_truth[i] == 1:
            true_positive += 1
        if ground_truth[i] == 1 and prediction[i] != ground_truth[i]:
            false_positive += 1
        if prediction[i] == ground_truth[i] == 0:
            true_negative += 1
        if ground_truth[i] == 0 and prediction[i] != ground_truth[i]:
            false_negative += 1
    try:
        precision = true_positive / (true_positive + false_positive)
        recall = true_positive / (true_positive + false_negative)
        accuracy = (true_positive + true_negative) / \
                (true_positive + true_negative + false_positive + false_negative)

        f1 = (1+b) * (precision * recall) / ((b**2 * precision) + recall)
        return precision, recall, f1, accuracy    
    except:
        return 0, 0, 0, 0


precision, recall, f1, _ = binary_classification_metrics(predictions, gt)
print("F1: %4.3f, P: %4.3f, R: %4.3f" % (f1, precision, recall))
# Out:
# F1: 0.898, P: 0.845, R: 0.960

# %% [markdown]
# # Что будет в конце вы уже поняли
#
# Натренируйте лучшую модель на основе `resnet18`, меняя только процесс тренировки.
# Выбирайте лучшую модель по F1 score.
#
# Как всегда, не забываем:
# - побольше агментаций!
# - перебор гиперпараметров
# - различные оптимизаторы
# - какие слои тюнить
# - learning rate annealing
# - на какой эпохе останавливаться
#
# Наша цель - довести F1 score на validation set до значения, большего **0.93**.

# %%
from collections import namedtuple
Hyperparams = namedtuple("Hyperparams", 
                         ['learning_rate1', 'learning_rate2', 'anneal_epochs', 
                          'r1', 'r2', 'epochs'])

RunResult = namedtuple("RunResult", ['model', 'optimizer', 
                                     'train_history', 'val_history', 'f1_val'])
run_record = {}

# %%
import torch.nn as nn
import torch.optim as optim

epoch = 6
anneal_epochs = [1, 2]
reg = [1e-4, 1e-3, 1e-2]
lrs = [1e-2, 1e-3, 1e-4]

for ae in anneal_epochs:
    for r1 in reg:
        for r2 in reg:
            for lr1 in lrs:
                for lr2 in lrs:
                    hprparams = Hyperparams(lr1, lr2, ae, r1, r2, epoch)
                    print(hprparams)

                    model = models.resnet18(pretrained=True)

                    num_ftrs = model.fc.in_features
                    model.fc = nn.Linear(num_ftrs, 2)
                    model.type(torch.cuda.FloatTensor)
                    model.to(device)

                    parameters = [{'params': list(model.parameters())[:-1],
                                 'lr':lr1, 'reg': r1}, 
                                {'params': list(model.parameters())[-1], 
                                 'lr': lr2, 'reg': r2}]

                    optimizer = optim.Adam(parameters)
                    loss = nn.CrossEntropyLoss()
                    loss_history, train_history, val_history = \
                                                  train_model(model, train_loader, 
                                                              val_loader, loss, 
                                                              optimizer, epoch)

                    predictions, gt = evaluate_model(model, train_dataset, val_indices)
                    precision, recall, f1, _ = \
                                      binary_classification_metrics(predictions, gt)

                    score = RunResult(model, optimizer, train_history, val_history, f1)
                    run_record[hprparams] = score
                    print(f"f1: {score.f1_val}")
# Out:
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.803152, Train accuracy: 0.654901, Val accuracy: 0.693750
# Average loss: 0.598585, Train accuracy: 0.672550, Val accuracy: 0.693056
# Average loss: 0.567915, Train accuracy: 0.697529, Val accuracy: 0.592361
# Average loss: 0.559200, Train accuracy: 0.707304, Val accuracy: 0.693056
# Average loss: 0.628228, Train accuracy: 0.732283, Val accuracy: 0.712500
# Average loss: 0.504420, Train accuracy: 0.761607, Val accuracy: 0.713194
# f1: 0.5931677018633542
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 1.065377, Train accuracy: 0.667662, Val accuracy: 0.683333
# Average loss: 0.595695, Train accuracy: 0.690198, Val accuracy: 0.686111
# Average loss: 0.560341, Train accuracy: 0.705132, Val accuracy: 0.734375
# Average loss: 0.571237, Train accuracy: 0.699430, Val accuracy: 0.691319
# Average loss: 0.539418, Train accuracy: 0.713549, Val accuracy: 0.743403
# Average loss: 0.493796, Train accuracy: 0.750747, Val accuracy: 0.738889
# f1: 0.6188197767145135
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.792781, Train accuracy: 0.647298, Val accuracy: 0.684028
# Average loss: 0.558901, Train accuracy: 0.703503, Val accuracy: 0.730556
# Average loss: 0.514079, Train accuracy: 0.731740, Val accuracy: 0.713889
# Average loss: 0.474076, Train accuracy: 0.767852, Val accuracy: 0.692708
# Average loss: 0.514519, Train accuracy: 0.740701, Val accuracy: 0.702083
# Average loss: 0.519470, Train accuracy: 0.756449, Val accuracy: 0.674653
# f1: 0.2897862232779097
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.361243, Train accuracy: 0.856639, Val accuracy: 0.826042
# Average loss: 0.234307, Train accuracy: 0.901439, Val accuracy: 0.910069
# Average loss: 0.139130, Train accuracy: 0.944339, Val accuracy: 0.871181
# Average loss: 0.110961, Train accuracy: 0.959272, Val accuracy: 0.897917
# Average loss: 0.102183, Train accuracy: 0.961444, Val accuracy: 0.748611
# Average loss: 0.088649, Train accuracy: 0.965517, Val accuracy: 0.877431
# f1: 0.7898550724637682
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.398381, Train accuracy: 0.833017, Val accuracy: 0.838194
# Average loss: 0.255241, Train accuracy: 0.890035, Val accuracy: 0.853472
# Average loss: 0.177909, Train accuracy: 0.930491, Val accuracy: 0.758333
# Average loss: 0.122177, Train accuracy: 0.953299, Val accuracy: 0.868403
# Average loss: 0.098557, Train accuracy: 0.962802, Val accuracy: 0.813542
# Average loss: 0.103054, Train accuracy: 0.961444, Val accuracy: 0.838889
# f1: 0.7771084337349399
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.377224, Train accuracy: 0.855010, Val accuracy: 0.809375
# Average loss: 0.188973, Train accuracy: 0.923704, Val accuracy: 0.900347
# Average loss: 0.133043, Train accuracy: 0.951127, Val accuracy: 0.915972
# Average loss: 0.110273, Train accuracy: 0.959544, Val accuracy: 0.888889
# Average loss: 0.095264, Train accuracy: 0.963345, Val accuracy: 0.866319
# Average loss: 0.094088, Train accuracy: 0.964974, Val accuracy: 0.897569
# f1: 0.8534201954397393
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.190264, Train accuracy: 0.924790, Val accuracy: 0.943403
# Average loss: 0.030468, Train accuracy: 0.992941, Val accuracy: 0.946181
# Average loss: 0.009740, Train accuracy: 0.998099, Val accuracy: 0.950347
# Average loss: 0.003149, Train accuracy: 0.999728, Val accuracy: 0.953125
# Average loss: 0.002449, Train accuracy: 0.999728, Val accuracy: 0.950347
# Average loss: 0.001239, Train accuracy: 1.000000, Val accuracy: 0.947569
# f1: 0.9134438305709024
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.234563, Train accuracy: 0.900896, Val accuracy: 0.918750
# Average loss: 0.038605, Train accuracy: 0.989411, Val accuracy: 0.950347
# Average loss: 0.006857, Train accuracy: 0.999728, Val accuracy: 0.957292
# Average loss: 0.004355, Train accuracy: 1.000000, Val accuracy: 0.951042
# Average loss: 0.001532, Train accuracy: 1.000000, Val accuracy: 0.945486
# Average loss: 0.001404, Train accuracy: 1.000000, Val accuracy: 0.955556
# f1: 0.9263913824057451
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.199931, Train accuracy: 0.916373, Val accuracy: 0.937500
# Average loss: 0.026985, Train accuracy: 0.994027, Val accuracy: 0.955208
# Average loss: 0.006232, Train accuracy: 0.999457, Val accuracy: 0.961458
# Average loss: 0.002699, Train accuracy: 1.000000, Val accuracy: 0.955556
# Average loss: 0.001683, Train accuracy: 1.000000, Val accuracy: 0.954167
# Average loss: 0.001113, Train accuracy: 1.000000, Val accuracy: 0.956250
# f1: 0.924187725631769
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.849648, Train accuracy: 0.658974, Val accuracy: 0.687847
# Average loss: 0.581122, Train accuracy: 0.686940, Val accuracy: 0.685764
# Average loss: 0.507970, Train accuracy: 0.736899, Val accuracy: 0.703819
# Average loss: 0.490532, Train accuracy: 0.748575, Val accuracy: 0.660417
# Average loss: 0.474870, Train accuracy: 0.766223, Val accuracy: 0.721181
# Average loss: 0.460636, Train accuracy: 0.780071, Val accuracy: 0.766667
# f1: 0.5466101694915255
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.819694, Train accuracy: 0.644040, Val accuracy: 0.698264
# Average loss: 0.565720, Train accuracy: 0.683953, Val accuracy: 0.694792
# Average loss: 0.556948, Train accuracy: 0.715992, Val accuracy: 0.697569
# Average loss: 0.538481, Train accuracy: 0.733641, Val accuracy: 0.697222
# Average loss: 0.506867, Train accuracy: 0.747488, Val accuracy: 0.680208
# Average loss: 0.472639, Train accuracy: 0.771925, Val accuracy: 0.734375
# f1: 0.5488029465930019
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.953189, Train accuracy: 0.648656, Val accuracy: 0.696528
# Average loss: 0.620592, Train accuracy: 0.685854, Val accuracy: 0.687153
# Average loss: 0.549577, Train accuracy: 0.712734, Val accuracy: 0.710069
# Average loss: 0.551922, Train accuracy: 0.725767, Val accuracy: 0.710764
# Average loss: 0.481957, Train accuracy: 0.767581, Val accuracy: 0.775694
# Average loss: 0.464149, Train accuracy: 0.780885, Val accuracy: 0.748611
# f1: 0.41895261845386533
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.362313, Train accuracy: 0.861797, Val accuracy: 0.853472
# Average loss: 0.192041, Train accuracy: 0.926419, Val accuracy: 0.904861
# Average loss: 0.129933, Train accuracy: 0.953842, Val accuracy: 0.896181
# Average loss: 0.150522, Train accuracy: 0.944339, Val accuracy: 0.892014
# Average loss: 0.121925, Train accuracy: 0.953842, Val accuracy: 0.872917
# Average loss: 0.075756, Train accuracy: 0.972577, Val accuracy: 0.877431
# f1: 0.778443113772455
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.394913, Train accuracy: 0.840619, Val accuracy: 0.870486
# Average loss: 0.226293, Train accuracy: 0.910128, Val accuracy: 0.876736
# Average loss: 0.167464, Train accuracy: 0.935379, Val accuracy: 0.789931
# Average loss: 0.133967, Train accuracy: 0.946511, Val accuracy: 0.870833
# Average loss: 0.116584, Train accuracy: 0.958729, Val accuracy: 0.892708
# Average loss: 0.066906, Train accuracy: 0.976921, Val accuracy: 0.892361
# f1: 0.846029173419773
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.362404, Train accuracy: 0.856096, Val accuracy: 0.543056
# Average loss: 0.177632, Train accuracy: 0.929134, Val accuracy: 0.874306
# Average loss: 0.160954, Train accuracy: 0.937822, Val accuracy: 0.884028
# Average loss: 0.106667, Train accuracy: 0.958729, Val accuracy: 0.873611
# Average loss: 0.105989, Train accuracy: 0.960358, Val accuracy: 0.890972
# Average loss: 0.081564, Train accuracy: 0.972034, Val accuracy: 0.899306
# f1: 0.8250460405156538
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.248108, Train accuracy: 0.888949, Val accuracy: 0.946875
# Average loss: 0.030882, Train accuracy: 0.992126, Val accuracy: 0.956597
# Average loss: 0.011184, Train accuracy: 0.997556, Val accuracy: 0.948264
# Average loss: 0.004242, Train accuracy: 0.999457, Val accuracy: 0.959722
# Average loss: 0.001828, Train accuracy: 1.000000, Val accuracy: 0.955208
# Average loss: 0.002262, Train accuracy: 1.000000, Val accuracy: 0.955556
# f1: 0.9263913824057451
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.195245, Train accuracy: 0.920445, Val accuracy: 0.926042
# Average loss: 0.028962, Train accuracy: 0.991854, Val accuracy: 0.954514
# Average loss: 0.008968, Train accuracy: 0.998371, Val accuracy: 0.950694
# Average loss: 0.004089, Train accuracy: 0.999457, Val accuracy: 0.960764
# Average loss: 0.002502, Train accuracy: 1.000000, Val accuracy: 0.956250
# Average loss: 0.001357, Train accuracy: 1.000000, Val accuracy: 0.952778
# f1: 0.924187725631769
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.191897, Train accuracy: 0.922346, Val accuracy: 0.953472
# Average loss: 0.026967, Train accuracy: 0.994841, Val accuracy: 0.951042
# Average loss: 0.010294, Train accuracy: 0.998099, Val accuracy: 0.948611
# Average loss: 0.003054, Train accuracy: 0.999728, Val accuracy: 0.952778
# Average loss: 0.001285, Train accuracy: 1.000000, Val accuracy: 0.951389
# Average loss: 0.002461, Train accuracy: 0.999457, Val accuracy: 0.947917
# f1: 0.910394265232975
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.847310, Train accuracy: 0.636166, Val accuracy: 0.475000
# Average loss: 0.596064, Train accuracy: 0.679881, Val accuracy: 0.640278
# Average loss: 0.563509, Train accuracy: 0.714092, Val accuracy: 0.655556
# Average loss: 0.571697, Train accuracy: 0.686125, Val accuracy: 0.694792
# Average loss: 0.497804, Train accuracy: 0.736628, Val accuracy: 0.690972
# Average loss: 0.484868, Train accuracy: 0.734999, Val accuracy: 0.655903
# f1: 0.611042944785276
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.985930, Train accuracy: 0.655172, Val accuracy: 0.661806
# Average loss: 0.607368, Train accuracy: 0.690470, Val accuracy: 0.709028
# Average loss: 0.511182, Train accuracy: 0.734999, Val accuracy: 0.431944
# Average loss: 0.545509, Train accuracy: 0.720065, Val accuracy: 0.650000
# Average loss: 0.534305, Train accuracy: 0.709476, Val accuracy: 0.753472
# Average loss: 0.489906, Train accuracy: 0.766495, Val accuracy: 0.734722
# f1: 0.5508317929759705
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.846405, Train accuracy: 0.660331, Val accuracy: 0.698264
# Average loss: 0.585479, Train accuracy: 0.686397, Val accuracy: 0.683333
# Average loss: 0.556098, Train accuracy: 0.693185, Val accuracy: 0.635069
# Average loss: 0.522809, Train accuracy: 0.723323, Val accuracy: 0.696528
# Average loss: 0.516008, Train accuracy: 0.730926, Val accuracy: 0.505903
# Average loss: 0.547771, Train accuracy: 0.716535, Val accuracy: 0.383333
# f1: 0.46341463414634143
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.374239, Train accuracy: 0.845778, Val accuracy: 0.878819
# Average loss: 0.195980, Train accuracy: 0.921803, Val accuracy: 0.898958
# Average loss: 0.126503, Train accuracy: 0.956014, Val accuracy: 0.890625
# Average loss: 0.123435, Train accuracy: 0.951941, Val accuracy: 0.904514
# Average loss: 0.089507, Train accuracy: 0.967418, Val accuracy: 0.864583
# Average loss: 0.079562, Train accuracy: 0.971219, Val accuracy: 0.771875
# f1: 0.43967828418230565
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.381719, Train accuracy: 0.844963, Val accuracy: 0.815972
# Average loss: 0.219092, Train accuracy: 0.906869, Val accuracy: 0.876389
# Average loss: 0.147775, Train accuracy: 0.942981, Val accuracy: 0.873958
# Average loss: 0.127833, Train accuracy: 0.950855, Val accuracy: 0.644792
# Average loss: 0.102740, Train accuracy: 0.960087, Val accuracy: 0.830903
# Average loss: 0.067476, Train accuracy: 0.979636, Val accuracy: 0.822569
# f1: 0.6124401913875597
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.359541, Train accuracy: 0.854738, Val accuracy: 0.813542
# Average loss: 0.193195, Train accuracy: 0.923704, Val accuracy: 0.764583
# Average loss: 0.139373, Train accuracy: 0.944610, Val accuracy: 0.876736
# Average loss: 0.111112, Train accuracy: 0.955471, Val accuracy: 0.912153
# Average loss: 0.084522, Train accuracy: 0.971219, Val accuracy: 0.855208
# Average loss: 0.098496, Train accuracy: 0.964974, Val accuracy: 0.828472
# f1: 0.6146341463414634
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.184854, Train accuracy: 0.929948, Val accuracy: 0.949306
# Average loss: 0.034653, Train accuracy: 0.988596, Val accuracy: 0.953125
# Average loss: 0.008625, Train accuracy: 0.998642, Val accuracy: 0.956944
# Average loss: 0.003336, Train accuracy: 1.000000, Val accuracy: 0.955903
# Average loss: 0.001491, Train accuracy: 1.000000, Val accuracy: 0.959375
# Average loss: 0.001528, Train accuracy: 0.999728, Val accuracy: 0.958333
# f1: 0.927007299270073
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.206965, Train accuracy: 0.915015, Val accuracy: 0.947222
# Average loss: 0.030540, Train accuracy: 0.992398, Val accuracy: 0.953472
# Average loss: 0.006166, Train accuracy: 0.999457, Val accuracy: 0.956250
# Average loss: 0.002916, Train accuracy: 1.000000, Val accuracy: 0.948958
# Average loss: 0.002478, Train accuracy: 1.000000, Val accuracy: 0.954861
# Average loss: 0.001768, Train accuracy: 1.000000, Val accuracy: 0.948958
# f1: 0.9202898550724637
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.203649, Train accuracy: 0.918273, Val accuracy: 0.935069
# Average loss: 0.034791, Train accuracy: 0.991583, Val accuracy: 0.947917
# Average loss: 0.010886, Train accuracy: 0.998099, Val accuracy: 0.950347
# Average loss: 0.003457, Train accuracy: 1.000000, Val accuracy: 0.953472
# Average loss: 0.001718, Train accuracy: 1.000000, Val accuracy: 0.958333
# Average loss: 0.001204, Train accuracy: 1.000000, Val accuracy: 0.956250
# f1: 0.924731182795699
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.813418, Train accuracy: 0.656530, Val accuracy: 0.687847
# Average loss: 0.559072, Train accuracy: 0.702145, Val accuracy: 0.613542
# Average loss: 0.513893, Train accuracy: 0.726310, Val accuracy: 0.695833
# Average loss: 0.503954, Train accuracy: 0.739614, Val accuracy: 0.725000
# Average loss: 0.493915, Train accuracy: 0.758892, Val accuracy: 0.556597
# Average loss: 0.501104, Train accuracy: 0.741244, Val accuracy: 0.719792
# f1: 0.4931506849315069
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.748473, Train accuracy: 0.643497, Val accuracy: 0.572222
# Average loss: 0.627419, Train accuracy: 0.671735, Val accuracy: 0.661806
# Average loss: 0.527241, Train accuracy: 0.721966, Val accuracy: 0.710417
# Average loss: 0.519614, Train accuracy: 0.745859, Val accuracy: 0.703125
# Average loss: 0.471128, Train accuracy: 0.759707, Val accuracy: 0.766319
# Average loss: 0.488250, Train accuracy: 0.747488, Val accuracy: 0.766319
# f1: 0.6355785837651121
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.749159, Train accuracy: 0.647570, Val accuracy: 0.687847
# Average loss: 0.562975, Train accuracy: 0.689112, Val accuracy: 0.697917
# Average loss: 0.519277, Train accuracy: 0.736628, Val accuracy: 0.712500
# Average loss: 0.497116, Train accuracy: 0.746402, Val accuracy: 0.639583
# Average loss: 0.528902, Train accuracy: 0.721966, Val accuracy: 0.680556
# Average loss: 0.547562, Train accuracy: 0.714092, Val accuracy: 0.681250
# f1: 0.6032171581769437
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.346087, Train accuracy: 0.858811, Val accuracy: 0.896528
# Average loss: 0.163382, Train accuracy: 0.931578, Val accuracy: 0.886806
# Average loss: 0.131547, Train accuracy: 0.948955, Val accuracy: 0.879167
# Average loss: 0.138192, Train accuracy: 0.944882, Val accuracy: 0.874653
# Average loss: 0.095248, Train accuracy: 0.963345, Val accuracy: 0.900694
# Average loss: 0.062719, Train accuracy: 0.978007, Val accuracy: 0.856597
# f1: 0.7265135699373695
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.346212, Train accuracy: 0.865327, Val accuracy: 0.805903
# Average loss: 0.198951, Train accuracy: 0.921803, Val accuracy: 0.910069
# Average loss: 0.154494, Train accuracy: 0.943796, Val accuracy: 0.893056
# Average loss: 0.131806, Train accuracy: 0.950312, Val accuracy: 0.855208
# Average loss: 0.085217, Train accuracy: 0.968504, Val accuracy: 0.893750
# Average loss: 0.087347, Train accuracy: 0.965246, Val accuracy: 0.805903
# f1: 0.7561643835616438
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.322224, Train accuracy: 0.872387, Val accuracy: 0.892014
# Average loss: 0.191816, Train accuracy: 0.923975, Val accuracy: 0.828819
# Average loss: 0.142387, Train accuracy: 0.942981, Val accuracy: 0.757639
# Average loss: 0.138974, Train accuracy: 0.949226, Val accuracy: 0.889583
# Average loss: 0.082439, Train accuracy: 0.967146, Val accuracy: 0.874306
# Average loss: 0.069317, Train accuracy: 0.973120, Val accuracy: 0.886111
# f1: 0.7818930041152263
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.203661, Train accuracy: 0.917730, Val accuracy: 0.938194
# Average loss: 0.027550, Train accuracy: 0.992126, Val accuracy: 0.953472
# Average loss: 0.007681, Train accuracy: 0.999457, Val accuracy: 0.950347
# Average loss: 0.003180, Train accuracy: 1.000000, Val accuracy: 0.956250
# Average loss: 0.002105, Train accuracy: 0.999728, Val accuracy: 0.952778
# Average loss: 0.001559, Train accuracy: 1.000000, Val accuracy: 0.949653
# f1: 0.9197860962566845
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.236187, Train accuracy: 0.902254, Val accuracy: 0.955208
# Average loss: 0.041836, Train accuracy: 0.988596, Val accuracy: 0.950347
# Average loss: 0.011184, Train accuracy: 0.998642, Val accuracy: 0.950694
# Average loss: 0.003805, Train accuracy: 0.999728, Val accuracy: 0.952778
# Average loss: 0.002537, Train accuracy: 1.000000, Val accuracy: 0.954514
# Average loss: 0.002004, Train accuracy: 1.000000, Val accuracy: 0.940625
# f1: 0.9033457249070632
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.195269, Train accuracy: 0.918545, Val accuracy: 0.940972
# Average loss: 0.026037, Train accuracy: 0.993484, Val accuracy: 0.953819
# Average loss: 0.006306, Train accuracy: 0.999185, Val accuracy: 0.950000
# Average loss: 0.004215, Train accuracy: 0.999457, Val accuracy: 0.952431
# Average loss: 0.004630, Train accuracy: 0.998914, Val accuracy: 0.948958
# Average loss: 0.004361, Train accuracy: 0.999185, Val accuracy: 0.954861
# f1: 0.9283154121863799
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.965170, Train accuracy: 0.657616, Val accuracy: 0.668750
# Average loss: 0.577790, Train accuracy: 0.701059, Val accuracy: 0.702431
# Average loss: 0.589377, Train accuracy: 0.709204, Val accuracy: 0.529167
# Average loss: 0.573197, Train accuracy: 0.727939, Val accuracy: 0.687153
# Average loss: 0.503638, Train accuracy: 0.744773, Val accuracy: 0.611806
# Average loss: 0.462102, Train accuracy: 0.776812, Val accuracy: 0.680556
# f1: 0.6194225721784777
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.811312, Train accuracy: 0.645126, Val accuracy: 0.687847
# Average loss: 0.581177, Train accuracy: 0.679337, Val accuracy: 0.691667
# Average loss: 0.548146, Train accuracy: 0.699701, Val accuracy: 0.637847
# Average loss: 0.485710, Train accuracy: 0.757535, Val accuracy: 0.623611
# Average loss: 0.501549, Train accuracy: 0.754819, Val accuracy: 0.711458
# Average loss: 0.480559, Train accuracy: 0.759435, Val accuracy: 0.721875
# f1: 0.2997275204359673
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.841320, Train accuracy: 0.648656, Val accuracy: 0.502083
# Average loss: 0.582267, Train accuracy: 0.694542, Val accuracy: 0.699653
# Average loss: 0.512918, Train accuracy: 0.741244, Val accuracy: 0.713889
# Average loss: 0.467228, Train accuracy: 0.762693, Val accuracy: 0.775347
# Average loss: 0.452538, Train accuracy: 0.787402, Val accuracy: 0.652083
# Average loss: 0.433194, Train accuracy: 0.796362, Val accuracy: 0.770486
# f1: 0.6227758007117438
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.366365, Train accuracy: 0.850665, Val accuracy: 0.848958
# Average loss: 0.208511, Train accuracy: 0.916644, Val accuracy: 0.901736
# Average loss: 0.136196, Train accuracy: 0.947054, Val accuracy: 0.820139
# Average loss: 0.113536, Train accuracy: 0.954385, Val accuracy: 0.869097
# Average loss: 0.102897, Train accuracy: 0.962531, Val accuracy: 0.802431
# Average loss: 0.089306, Train accuracy: 0.967961, Val accuracy: 0.877778
# f1: 0.7594936708860759
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.379469, Train accuracy: 0.850665, Val accuracy: 0.879167
# Average loss: 0.205606, Train accuracy: 0.921531, Val accuracy: 0.844792
# Average loss: 0.174794, Train accuracy: 0.929134, Val accuracy: 0.903819
# Average loss: 0.100027, Train accuracy: 0.960630, Val accuracy: 0.898264
# Average loss: 0.101156, Train accuracy: 0.964160, Val accuracy: 0.862500
# Average loss: 0.090944, Train accuracy: 0.966332, Val accuracy: 0.873264
# f1: 0.8020654044750432
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.342081, Train accuracy: 0.859625, Val accuracy: 0.850000
# Average loss: 0.208425, Train accuracy: 0.920174, Val accuracy: 0.894792
# Average loss: 0.148972, Train accuracy: 0.941352, Val accuracy: 0.786458
# Average loss: 0.121901, Train accuracy: 0.953299, Val accuracy: 0.889931
# Average loss: 0.097138, Train accuracy: 0.964431, Val accuracy: 0.898611
# Average loss: 0.072372, Train accuracy: 0.974206, Val accuracy: 0.898611
# f1: 0.81640625
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.176663, Train accuracy: 0.931306, Val accuracy: 0.947917
# Average loss: 0.032041, Train accuracy: 0.991311, Val accuracy: 0.942014
# Average loss: 0.007619, Train accuracy: 0.999728, Val accuracy: 0.956250
# Average loss: 0.002334, Train accuracy: 1.000000, Val accuracy: 0.954514
# Average loss: 0.001741, Train accuracy: 1.000000, Val accuracy: 0.959375
# Average loss: 0.001336, Train accuracy: 1.000000, Val accuracy: 0.958681
# f1: 0.9316546762589927
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.219372, Train accuracy: 0.909585, Val accuracy: 0.943056
# Average loss: 0.030995, Train accuracy: 0.993212, Val accuracy: 0.951736
# Average loss: 0.006541, Train accuracy: 0.999457, Val accuracy: 0.959375
# Average loss: 0.002781, Train accuracy: 1.000000, Val accuracy: 0.958333
# Average loss: 0.002731, Train accuracy: 0.999457, Val accuracy: 0.949653
# Average loss: 0.001174, Train accuracy: 1.000000, Val accuracy: 0.955556
# f1: 0.9263913824057451
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.214069, Train accuracy: 0.916916, Val accuracy: 0.953472
# Average loss: 0.034255, Train accuracy: 0.989411, Val accuracy: 0.948264
# Average loss: 0.007814, Train accuracy: 0.998914, Val accuracy: 0.957292
# Average loss: 0.003465, Train accuracy: 0.999728, Val accuracy: 0.951736
# Average loss: 0.001590, Train accuracy: 1.000000, Val accuracy: 0.959375
# Average loss: 0.001176, Train accuracy: 1.000000, Val accuracy: 0.955556
# f1: 0.9258589511754068
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.01, epochs=6)
# Average loss: 0.796030, Train accuracy: 0.655444, Val accuracy: 0.685764
# Average loss: 0.552732, Train accuracy: 0.695357, Val accuracy: 0.563542
# Average loss: 0.562811, Train accuracy: 0.730926, Val accuracy: 0.681944
# Average loss: 0.518372, Train accuracy: 0.723595, Val accuracy: 0.682986
# Average loss: 0.490856, Train accuracy: 0.746131, Val accuracy: 0.723611
# Average loss: 0.482140, Train accuracy: 0.755091, Val accuracy: 0.743056
# f1: 0.6251993620414673
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.01, epochs=6)
# Average loss: 0.762499, Train accuracy: 0.647298, Val accuracy: 0.694444
# Average loss: 0.569508, Train accuracy: 0.710562, Val accuracy: 0.691319
# Average loss: 0.533384, Train accuracy: 0.718165, Val accuracy: 0.724653
# Average loss: 0.522161, Train accuracy: 0.733098, Val accuracy: 0.647222
# Average loss: 0.547843, Train accuracy: 0.745588, Val accuracy: 0.742708
# Average loss: 0.482632, Train accuracy: 0.766495, Val accuracy: 0.750347
# f1: 0.5890652557319224
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.01, epochs=6)
# Average loss: 0.958376, Train accuracy: 0.653543, Val accuracy: 0.693056
# Average loss: 0.577365, Train accuracy: 0.690741, Val accuracy: 0.680208
# Average loss: 0.527511, Train accuracy: 0.713820, Val accuracy: 0.730556
# Average loss: 0.518144, Train accuracy: 0.730383, Val accuracy: 0.703125
# Average loss: 0.493659, Train accuracy: 0.745045, Val accuracy: 0.725347
# Average loss: 0.483111, Train accuracy: 0.757806, Val accuracy: 0.723611
# f1: 0.5483870967741935
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.01, epochs=6)
# Average loss: 0.348430, Train accuracy: 0.863970, Val accuracy: 0.855208
# Average loss: 0.183401, Train accuracy: 0.925061, Val accuracy: 0.812500
# Average loss: 0.133394, Train accuracy: 0.947597, Val accuracy: 0.899306
# Average loss: 0.130512, Train accuracy: 0.950041, Val accuracy: 0.883333
# Average loss: 0.108835, Train accuracy: 0.960087, Val accuracy: 0.878125
# Average loss: 0.082673, Train accuracy: 0.969318, Val accuracy: 0.893750
# f1: 0.8289241622574957
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.01, epochs=6)
# Average loss: 0.363740, Train accuracy: 0.852566, Val accuracy: 0.873611
# Average loss: 0.193899, Train accuracy: 0.924518, Val accuracy: 0.869444
# Average loss: 0.153644, Train accuracy: 0.936465, Val accuracy: 0.881944
# Average loss: 0.127446, Train accuracy: 0.953299, Val accuracy: 0.898611
# Average loss: 0.080960, Train accuracy: 0.970405, Val accuracy: 0.890972
# Average loss: 0.088048, Train accuracy: 0.964703, Val accuracy: 0.864931
# f1: 0.7714285714285714
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.01, epochs=6)
# Average loss: 0.415559, Train accuracy: 0.840891, Val accuracy: 0.837847
# Average loss: 0.241459, Train accuracy: 0.897909, Val accuracy: 0.889931
# Average loss: 0.164078, Train accuracy: 0.937008, Val accuracy: 0.879514
# Average loss: 0.128146, Train accuracy: 0.949226, Val accuracy: 0.877778
# Average loss: 0.102165, Train accuracy: 0.963345, Val accuracy: 0.904167
# Average loss: 0.084186, Train accuracy: 0.967418, Val accuracy: 0.871875
# f1: 0.7937062937062936
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.01, epochs=6)
# Average loss: 0.239639, Train accuracy: 0.898452, Val accuracy: 0.950000
# Average loss: 0.034175, Train accuracy: 0.989411, Val accuracy: 0.951736
# Average loss: 0.007414, Train accuracy: 0.999457, Val accuracy: 0.953472
# Average loss: 0.003044, Train accuracy: 1.000000, Val accuracy: 0.955903
# Average loss: 0.002237, Train accuracy: 1.000000, Val accuracy: 0.957639
# Average loss: 0.002678, Train accuracy: 1.000000, Val accuracy: 0.953472
# f1: 0.9233511586452763
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.01, epochs=6)
# Average loss: 0.214648, Train accuracy: 0.909313, Val accuracy: 0.948958
# Average loss: 0.038328, Train accuracy: 0.988868, Val accuracy: 0.958681
# Average loss: 0.010254, Train accuracy: 0.998914, Val accuracy: 0.952431
# Average loss: 0.003049, Train accuracy: 1.000000, Val accuracy: 0.954514
# Average loss: 0.002558, Train accuracy: 1.000000, Val accuracy: 0.954861
# Average loss: 0.001431, Train accuracy: 1.000000, Val accuracy: 0.960417
# f1: 0.9316546762589927
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.01, epochs=6)
# Average loss: 0.210458, Train accuracy: 0.915829, Val accuracy: 0.949306
# Average loss: 0.027347, Train accuracy: 0.993212, Val accuracy: 0.946875
# Average loss: 0.008742, Train accuracy: 0.999185, Val accuracy: 0.948958
# Average loss: 0.002620, Train accuracy: 1.000000, Val accuracy: 0.948958
# Average loss: 0.002259, Train accuracy: 0.999728, Val accuracy: 0.950000
# Average loss: 0.001122, Train accuracy: 1.000000, Val accuracy: 0.953125
# f1: 0.9177330895795247
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.01, r2=0.0001, epochs=6)
# Average loss: 0.741803, Train accuracy: 0.669563, Val accuracy: 0.696528
# Average loss: 0.703374, Train accuracy: 0.663589, Val accuracy: 0.701736
# Average loss: 0.591802, Train accuracy: 0.686125, Val accuracy: 0.688889
# Average loss: 0.515744, Train accuracy: 0.721966, Val accuracy: 0.738542
# Average loss: 0.482694, Train accuracy: 0.746131, Val accuracy: 0.657986
# Average loss: 0.462313, Train accuracy: 0.775726, Val accuracy: 0.732292
# f1: 0.5983739837398373
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.01, r2=0.0001, epochs=6)
# Average loss: 0.795550, Train accuracy: 0.640239, Val accuracy: 0.693056
# Average loss: 0.588852, Train accuracy: 0.684768, Val accuracy: 0.722569
# Average loss: 0.540734, Train accuracy: 0.707575, Val accuracy: 0.680556
# Average loss: 0.502538, Train accuracy: 0.744230, Val accuracy: 0.755208
# Average loss: 0.474063, Train accuracy: 0.762693, Val accuracy: 0.550000
# Average loss: 0.471490, Train accuracy: 0.768667, Val accuracy: 0.766319
# f1: 0.6285714285714287
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.01, r2=0.0001, epochs=6)
# Average loss: 0.812999, Train accuracy: 0.643226, Val accuracy: 0.690625
# Average loss: 0.538637, Train accuracy: 0.708118, Val accuracy: 0.698611
# Average loss: 0.526322, Train accuracy: 0.732827, Val accuracy: 0.737847
# Average loss: 0.496911, Train accuracy: 0.762965, Val accuracy: 0.757292
# Average loss: 0.456365, Train accuracy: 0.775455, Val accuracy: 0.673264
# Average loss: 0.458309, Train accuracy: 0.778170, Val accuracy: 0.769792
# f1: 0.6666666666666666
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.01, r2=0.0001, epochs=6)
# Average loss: 0.394102, Train accuracy: 0.840891, Val accuracy: 0.773958
# Average loss: 0.215171, Train accuracy: 0.910671, Val accuracy: 0.846528
# Average loss: 0.169712, Train accuracy: 0.939723, Val accuracy: 0.814931
# Average loss: 0.134703, Train accuracy: 0.949769, Val accuracy: 0.862153
# Average loss: 0.117896, Train accuracy: 0.953299, Val accuracy: 0.836806
# Average loss: 0.067736, Train accuracy: 0.975020, Val accuracy: 0.867361
# f1: 0.7292576419213972
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.01, r2=0.0001, epochs=6)
# Average loss: 0.361571, Train accuracy: 0.856910, Val accuracy: 0.867361
# Average loss: 0.200999, Train accuracy: 0.926147, Val accuracy: 0.883681
# Average loss: 0.159758, Train accuracy: 0.935379, Val accuracy: 0.886806
# Average loss: 0.135638, Train accuracy: 0.952484, Val accuracy: 0.896875
# Average loss: 0.096205, Train accuracy: 0.966875, Val accuracy: 0.903819
# Average loss: 0.078779, Train accuracy: 0.969862, Val accuracy: 0.881250
# f1: 0.7625
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.01, r2=0.0001, epochs=6)
# Average loss: 0.359907, Train accuracy: 0.856910, Val accuracy: 0.897222
# Average loss: 0.201512, Train accuracy: 0.922074, Val accuracy: 0.852778
# Average loss: 0.151828, Train accuracy: 0.939180, Val accuracy: 0.851736
# Average loss: 0.096211, Train accuracy: 0.964974, Val accuracy: 0.902778
# Average loss: 0.102214, Train accuracy: 0.963617, Val accuracy: 0.903125
# Average loss: 0.069340, Train accuracy: 0.980451, Val accuracy: 0.903125
# f1: 0.8399311531841653
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.01, r2=0.0001, epochs=6)
# Average loss: 0.207473, Train accuracy: 0.914743, Val accuracy: 0.944097
# Average loss: 0.040464, Train accuracy: 0.987782, Val accuracy: 0.942014
# Average loss: 0.011511, Train accuracy: 0.997556, Val accuracy: 0.943403
# Average loss: 0.003735, Train accuracy: 1.000000, Val accuracy: 0.942361
# Average loss: 0.001675, Train accuracy: 1.000000, Val accuracy: 0.940278
# Average loss: 0.001416, Train accuracy: 1.000000, Val accuracy: 0.948958
# f1: 0.9113924050632911
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.01, r2=0.0001, epochs=6)
# Average loss: 0.204728, Train accuracy: 0.913657, Val accuracy: 0.940972
# Average loss: 0.031838, Train accuracy: 0.992941, Val accuracy: 0.945486
# Average loss: 0.005499, Train accuracy: 1.000000, Val accuracy: 0.959375
# Average loss: 0.004139, Train accuracy: 0.999728, Val accuracy: 0.946528
# Average loss: 0.002602, Train accuracy: 0.999728, Val accuracy: 0.955208
# Average loss: 0.001495, Train accuracy: 1.000000, Val accuracy: 0.956250
# f1: 0.9244604316546763
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.01, r2=0.0001, epochs=6)
# Average loss: 0.195016, Train accuracy: 0.915286, Val accuracy: 0.949306
# Average loss: 0.034663, Train accuracy: 0.990497, Val accuracy: 0.947222
# Average loss: 0.006986, Train accuracy: 0.999728, Val accuracy: 0.947569
# Average loss: 0.003333, Train accuracy: 0.999728, Val accuracy: 0.953819
# Average loss: 0.002989, Train accuracy: 0.999457, Val accuracy: 0.950347
# Average loss: 0.001968, Train accuracy: 0.999728, Val accuracy: 0.956250
# f1: 0.9257950530035336
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.01, r2=0.001, epochs=6)
# Average loss: 0.864351, Train accuracy: 0.626663, Val accuracy: 0.588542
# Average loss: 0.622944, Train accuracy: 0.674450, Val accuracy: 0.670139
# Average loss: 0.537758, Train accuracy: 0.721151, Val accuracy: 0.702431
# Average loss: 0.486408, Train accuracy: 0.762150, Val accuracy: 0.694792
# Average loss: 0.456394, Train accuracy: 0.782514, Val accuracy: 0.718056
# Average loss: 0.471478, Train accuracy: 0.787130, Val accuracy: 0.598611
# f1: 0.5790697674418606
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.01, r2=0.001, epochs=6)
# Average loss: 0.895646, Train accuracy: 0.658159, Val accuracy: 0.689583
# Average loss: 0.599651, Train accuracy: 0.673907, Val accuracy: 0.682639
# Average loss: 0.562867, Train accuracy: 0.687755, Val accuracy: 0.691319
# Average loss: 0.503598, Train accuracy: 0.734184, Val accuracy: 0.488542
# Average loss: 0.488404, Train accuracy: 0.743687, Val accuracy: 0.753125
# Average loss: 0.527590, Train accuracy: 0.713820, Val accuracy: 0.712500
# f1: 0.23563218390804597
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.01, r2=0.001, epochs=6)
# Average loss: 0.703102, Train accuracy: 0.665219, Val accuracy: 0.659722
# Average loss: 0.711734, Train accuracy: 0.689112, Val accuracy: 0.660764
# Average loss: 0.536243, Train accuracy: 0.717350, Val accuracy: 0.713542
# Average loss: 0.497958, Train accuracy: 0.755362, Val accuracy: 0.730903
# Average loss: 0.484719, Train accuracy: 0.745045, Val accuracy: 0.756597
# Average loss: 0.468945, Train accuracy: 0.770296, Val accuracy: 0.720833
# f1: 0.5747899159663865
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.01, r2=0.001, epochs=6)
# Average loss: 0.345919, Train accuracy: 0.865056, Val accuracy: 0.846528
# Average loss: 0.203393, Train accuracy: 0.917459, Val accuracy: 0.884375
# Average loss: 0.150002, Train accuracy: 0.937822, Val accuracy: 0.910764
# Average loss: 0.112042, Train accuracy: 0.957100, Val accuracy: 0.912500
# Average loss: 0.113500, Train accuracy: 0.961988, Val accuracy: 0.836458
# Average loss: 0.083218, Train accuracy: 0.970676, Val accuracy: 0.825347
# f1: 0.7722772277227723
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.01, r2=0.001, epochs=6)
# Average loss: 0.357705, Train accuracy: 0.856639, Val accuracy: 0.880208
# Average loss: 0.198873, Train accuracy: 0.927233, Val accuracy: 0.844097
# Average loss: 0.152196, Train accuracy: 0.939452, Val accuracy: 0.865972
# Average loss: 0.125830, Train accuracy: 0.954657, Val accuracy: 0.821528
# Average loss: 0.108851, Train accuracy: 0.956557, Val accuracy: 0.807639
# Average loss: 0.091341, Train accuracy: 0.969862, Val accuracy: 0.873958
# f1: 0.77431906614786
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.01, r2=0.001, epochs=6)
# Average loss: 0.414874, Train accuracy: 0.838718, Val accuracy: 0.852431
# Average loss: 0.225913, Train accuracy: 0.909856, Val accuracy: 0.875347
# Average loss: 0.166570, Train accuracy: 0.937551, Val accuracy: 0.800000
# Average loss: 0.136784, Train accuracy: 0.947869, Val accuracy: 0.825000
# Average loss: 0.114204, Train accuracy: 0.960901, Val accuracy: 0.843750
# Average loss: 0.121506, Train accuracy: 0.956014, Val accuracy: 0.846181
# f1: 0.7081545064377682
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.01, r2=0.001, epochs=6)
# Average loss: 0.201250, Train accuracy: 0.918545, Val accuracy: 0.946528
# Average loss: 0.029386, Train accuracy: 0.991583, Val accuracy: 0.960417
# Average loss: 0.008812, Train accuracy: 0.998099, Val accuracy: 0.949306
# Average loss: 0.003021, Train accuracy: 1.000000, Val accuracy: 0.953125
# Average loss: 0.001383, Train accuracy: 1.000000, Val accuracy: 0.955556
# Average loss: 0.001231, Train accuracy: 1.000000, Val accuracy: 0.949653
# f1: 0.9171270718232044
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.01, r2=0.001, epochs=6)
# Average loss: 0.192560, Train accuracy: 0.927505, Val accuracy: 0.957292
# Average loss: 0.028829, Train accuracy: 0.992941, Val accuracy: 0.952778
# Average loss: 0.006886, Train accuracy: 0.999457, Val accuracy: 0.964583
# Average loss: 0.003410, Train accuracy: 0.999728, Val accuracy: 0.953472
# Average loss: 0.003512, Train accuracy: 0.999457, Val accuracy: 0.959375
# Average loss: 0.008212, Train accuracy: 0.997556, Val accuracy: 0.952431
# f1: 0.9199999999999999
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.01, r2=0.001, epochs=6)
# Average loss: 0.189890, Train accuracy: 0.923704, Val accuracy: 0.947917
# Average loss: 0.025055, Train accuracy: 0.995113, Val accuracy: 0.948611
# Average loss: 0.008528, Train accuracy: 0.998914, Val accuracy: 0.950694
# Average loss: 0.004366, Train accuracy: 0.999457, Val accuracy: 0.949653
# Average loss: 0.001439, Train accuracy: 1.000000, Val accuracy: 0.953472
# Average loss: 0.001381, Train accuracy: 1.000000, Val accuracy: 0.948264
# f1: 0.9133574007220215
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.01, r2=0.01, epochs=6)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-40-e2f3da9a0192> in <module>()
#      31                     loss_history, train_history, val_history =                                                   train_model(model, train_loader,
#      32                                                               val_loader, loss,
# ---> 33                                                               optimizer, epoch)
#      34
#      35                     predictions, gt = evaluate_model(model, train_dataset, val_indices)
#
# <ipython-input-28-8aac8872955d> in train_model(model, train_loader, val_loader, loss, optimizer, num_epochs)
#      16             loss_value = loss(prediction, y_gpu)
#      17             optimizer.zero_grad()
# ---> 18             loss_value.backward()
#      19             optimizer.step()
#      20
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     196                 products. Defaults to ``False``.
#     197         """
# --> 198         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     199
#     200     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      98     Variable._execution_engine.run_backward(
#      99         tensors, grad_tensors, retain_graph, create_graph,
# --> 100         allow_unreachable=True)  # allow_unreachable flag
#     101
#     102
#
# RuntimeError: CUDA out of memory. Tried to allocate 196.00 MiB (GPU 0; 14.73 GiB total capacity; 12.93 GiB already allocated; 69.88 MiB free; 13.89 GiB reserved in total by PyTorch) (malloc at /pytorch/c10/cuda/CUDACachingAllocator.cpp:289)
# frame #0: c10::Error::Error(c10::SourceLocation, std::string const&) + 0x46 (0x7fa99abc5536 in /usr/local/lib/python3.6/dist-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0x1cf1e (0x7fa99ae0ef1e in /usr/local/lib/python3.6/dist-packages/torch/lib/libc10_cuda.so)
# frame #2: <unknown function> + 0x1df9e (0x7fa99ae0ff9e in /usr/local/lib/python3.6/dist-packages/torch/lib/libc10_cuda.so)
# frame #3: at::native::empty_cuda(c10::ArrayRef<long>, c10::TensorOptions const&, c10::optional<c10::MemoryFormat>) + 0x135 (0x7fa99d9bbfd5 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0xf9310b (0x7fa99bfb410b in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #5: <unknown function> + 0xfdc9f7 (0x7fa99bffd9f7 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #6: <unknown function> + 0x1075389 (0x7fa9d3948389 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #7: <unknown function> + 0x10756c7 (0x7fa9d39486c7 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #8: <unknown function> + 0xe3c42e (0x7fa9d370f42e in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #9: at::TensorIterator::fast_set_up() + 0x5cf (0x7fa9d37102af in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #10: at::TensorIterator::build() + 0x4c (0x7fa9d3710b6c in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #11: at::TensorIterator::binary_op(at::Tensor&, at::Tensor const&, at::Tensor const&, bool) + 0x146 (0x7fa9d3711216 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #12: <unknown function> + 0x19dc0c0 (0x7fa99c9fd0c0 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #13: at::native::threshold_backward_cuda(at::Tensor const&, at::Tensor const&, c10::Scalar) + 0x49 (0x7fa99c9feb79 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #14: <unknown function> + 0xfa4e9f (0x7fa99bfc5e9f in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #15: <unknown function> + 0x10c599b (0x7fa9d399899b in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #16: <unknown function> + 0x2d50baa (0x7fa9d5623baa in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #17: <unknown function> + 0x10c599b (0x7fa9d399899b in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #18: <unknown function> + 0x28b79af (0x7fa9d518a9af in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #19: torch::autograd::generated::ReluBackward1::apply(std::vector<at::Tensor, std::allocator<at::Tensor> >&&) + 0x112 (0x7fa9d518ad52 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #20: <unknown function> + 0x2d89c05 (0x7fa9d565cc05 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #21: torch::autograd::Engine::evaluate_function(std::shared_ptr<torch::autograd::GraphTask>&, torch::autograd::Node*, torch::autograd::InputBuffer&) + 0x16f3 (0x7fa9d5659f03 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #22: torch::autograd::Engine::thread_main(std::shared_ptr<torch::autograd::GraphTask> const&, bool) + 0x3d2 (0x7fa9d565ace2 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #23: torch::autograd::Engine::thread_init(int) + 0x39 (0x7fa9d5653359 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #24: torch::autograd::python::PythonEngine::thread_init(int) + 0x38 (0x7fa9e1d92378 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_python.so)
# frame #25: <unknown function> + 0xbd6df (0x7faa061a56df in /usr/lib/x86_64-linux-gnu/libstdc++.so.6)
# frame #26: <unknown function> + 0x76db (0x7faa072876db in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #27: clone + 0x3f (0x7faa075c088f in /lib/x86_64-linux-gnu/libc.so.6)

# %% [markdown]
# ## Визуализируйте ошибки лучшей модели

# %%
best_model = None
best_val_f1 = None
best_hyperparams = None
best_run = None

for hyperparams, run_result in run_record.items():
    if best_val_f1 is None or best_val_f1 < run_result.f1_val:
        best_val_f1 = run_result.f1_val
        best_hyperparams = hyperparams
        best_run = run_result 
        best_model = run_result.model

print("Best validation f1: %4.2f, best hyperparams: %s" % (best_val_f1, best_hyperparams))
# Out:
# Best validation f1: 0.93, best hyperparams: Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
